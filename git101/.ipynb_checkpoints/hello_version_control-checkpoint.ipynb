# %%
a = 20 
b = 10
c = a+b 
print(c)
# Out:
# 15

# %%
# !pip install matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = range(15)
plt.plot(x, [data*data for data in x])
plt.show()
